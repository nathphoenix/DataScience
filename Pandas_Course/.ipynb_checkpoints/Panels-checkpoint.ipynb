# %%
import pandas as pd
from pandas_datareader import data
import pandas_datareader.data as web
import datetime as dt

# %%
# companies = ["MSFT", "GOOG", "AAPL", "Y", "AMZN"]
mask = pd.Panel(dict((stock, web.get_data_yahoo(stock, start = "2010-01-01", end = "2016-12-31")) 
                      for stock in ["MSFT", "GOOG", "AAPL", "Y", "AMZN"]))
mask


# companies = ["MSFT", "GOOG", "AAPL", "Y", "AMZN"]
# mask = web.get_data_yahoo(name = companies, data_source = "yahoo", start = "2010-01-01", end = "2016-12-31")
# mask


# new = mask.to_xarray()
# mask.set_index(["2010-01-01", "2016-12-31"]).to_panel()
# mask.to_csv("financial")
# mask.to_panel()
# mask.set_index(["MSFT", "GOOG"]).to_panel()
# Out:
# C:\Users\Maxwell\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2963: FutureWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# <class 'pandas.core.panel.Panel'>
# Dimensions: 5 (items) x 1762 (major_axis) x 6 (minor_axis)
# Items axis: MSFT to AMZN
# Major_axis axis: 2010-01-04 00:00:00 to 2016-12-30 00:00:00
# Minor_axis axis: High to Adj Close

# %%
mask.items
# Out:
# Index(['MSFT', 'GOOG', 'AAPL', 'Y', 'AMZN'], dtype='object')

# %%
mask.major_axis
# Out:
# DatetimeIndex(['2010-01-04', '2010-01-05', '2010-01-06', '2010-01-07',
#                '2010-01-08', '2010-01-11', '2010-01-12', '2010-01-13',
#                '2010-01-14', '2010-01-15',
#                ...
#                '2016-12-16', '2016-12-19', '2016-12-20', '2016-12-21',
#                '2016-12-22', '2016-12-23', '2016-12-27', '2016-12-28',
#                '2016-12-29', '2016-12-30'],
#               dtype='datetime64[ns]', name='Date', length=1762, freq=None)

# %%
#column is the minor axis
mask.minor_axis
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
#this will return  an array of the ais that makes up the panel 
mask.axes
# Out:
# [Index(['MSFT', 'GOOG', 'AAPL', 'Y', 'AMZN'], dtype='object'),
#  DatetimeIndex(['2010-01-04', '2010-01-05', '2010-01-06', '2010-01-07',
#                 '2010-01-08', '2010-01-11', '2010-01-12', '2010-01-13',
#                 '2010-01-14', '2010-01-15',
#                 ...
#                 '2016-12-16', '2016-12-19', '2016-12-20', '2016-12-21',
#                 '2016-12-22', '2016-12-23', '2016-12-27', '2016-12-28',
#                 '2016-12-29', '2016-12-30'],
#                dtype='datetime64[ns]', name='Date', length=1762, freq=None),
#  Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')]

# %%
mask.ndim
# Out:
# 3

# %%
mask.dtypes
# Out:
# MSFT    float64
# GOOG    float64
# AAPL    float64
# Y       float64
# AMZN    float64
# dtype: object

# %%
#this gives us a tupple that gives us the measurements of the panel
mask.shape
# Out:
# (5, 1762, 6)

# %%
#totall amount odf datas on the panel
mask.size
# Out:
# 52860

# %%
#this returns a nested array
mask.values
# Out:
# array([[[3.11000004e+01, 3.05900002e+01, 3.06200008e+01, 3.09500008e+01,
#          3.84091000e+07, 2.45250187e+01],
#         [3.11000004e+01, 3.06399994e+01, 3.08500004e+01, 3.09599991e+01,
#          4.97496000e+07, 2.45329418e+01],
#         [3.10799999e+01, 3.05200005e+01, 3.08799992e+01, 3.07700005e+01,
#          5.81824000e+07, 2.43823776e+01],
#         ...,
#         [6.34000015e+01, 6.28300018e+01, 6.34000015e+01, 6.29900017e+01,
#          1.46533000e+07, 6.00857849e+01],
#         [6.32000008e+01, 6.27299995e+01, 6.28600006e+01, 6.29000015e+01,
#          1.02506000e+07, 5.99999390e+01],
#         [6.29900017e+01, 6.20299988e+01, 6.29599991e+01, 6.21399994e+01,
#          2.55799000e+07, 5.92749748e+01]],
#
#        [[3.13579620e+02, 3.10954468e+02, 3.12304413e+02, 3.12204773e+02,
#          3.92700000e+06, 3.12204773e+02],
#         [3.12747742e+02, 3.09609497e+02, 3.12418976e+02, 3.10829926e+02,
#          6.03190000e+06, 3.10829926e+02],
#         [3.11761444e+02, 3.02047852e+02, 3.11761444e+02, 3.02994293e+02,
#          7.98710000e+06, 3.02994293e+02],
#         ...,
#         [7.94229980e+02, 7.83200012e+02, 7.93700012e+02, 7.85049988e+02,
#          1.15380000e+06, 7.85049988e+02],
#         [7.85929993e+02, 7.78919983e+02, 7.83330017e+02, 7.82789978e+02,
#          7.44300000e+05, 7.82789978e+02],
#         [7.82780029e+02, 7.70409973e+02, 7.82750000e+02, 7.71820007e+02,
#          1.77000000e+06, 7.71820007e+02]],
#
#        [[3.06428566e+01, 3.03400002e+01, 3.04899998e+01, 3.05728569e+01,
#          1.23432400e+08, 2.67827110e+01],
#         [3.07985706e+01, 3.04642849e+01, 3.06571426e+01, 3.06257133e+01,
#          1.50476200e+08, 2.68290100e+01],
#         [3.07471428e+01, 3.01071434e+01, 3.06257133e+01, 3.01385708e+01,
#          1.38040000e+08, 2.64022598e+01],
#         ...,
#         [1.18019997e+02, 1.16199997e+02, 1.17519997e+02, 1.16760002e+02,
#          2.09059000e+07, 1.12296501e+02],
#         [1.17110001e+02, 1.16400002e+02, 1.16449997e+02, 1.16730003e+02,
#          1.50395000e+07, 1.12267647e+02],
#         [1.17199997e+02, 1.15430000e+02, 1.16650002e+02, 1.15820000e+02,
#          3.05863000e+07, 1.11392426e+02]],
#
#        [[2.66512878e+02, 2.61178406e+02, 2.66512878e+02, 2.63408295e+02,
#          1.46000000e+04, 2.58972778e+02],
#         [2.65138397e+02, 2.60159546e+02, 2.65138397e+02, 2.63312195e+02,
#          9.60000000e+03, 2.58878296e+02],
#         [2.63398682e+02, 2.59515564e+02, 2.61956940e+02, 2.63398682e+02,
#          1.81000000e+04, 2.58963318e+02],
#         ...,
#         [6.12000000e+02, 6.05219971e+02, 6.12000000e+02, 6.05429993e+02,
#          2.38000000e+04, 5.95235168e+02],
#         [6.11190002e+02, 6.04559998e+02, 6.04559998e+02, 6.09190002e+02,
#          2.80000000e+04, 5.98931885e+02],
#         [6.13419983e+02, 6.06150024e+02, 6.11989990e+02, 6.08119995e+02,
#          2.82000000e+04, 5.97879883e+02]],
#
#        [[1.36610001e+02, 1.33139999e+02, 1.36250000e+02, 1.33899994e+02,
#          7.59990000e+06, 1.33899994e+02],
#         [1.35479996e+02, 1.31809998e+02, 1.33429993e+02, 1.34690002e+02,
#          8.85190000e+06, 1.34690002e+02],
#         [1.34729996e+02, 1.31649994e+02, 1.34600006e+02, 1.32250000e+02,
#          7.17880000e+06, 1.32250000e+02],
#         ...,
#         [7.80000000e+02, 7.70500000e+02, 7.76250000e+02, 7.72130005e+02,
#          3.30100000e+06, 7.72130005e+02],
#         [7.73400024e+02, 7.60849976e+02, 7.72400024e+02, 7.65150024e+02,
#          3.15830000e+06, 7.65150024e+02],
#         [7.67400024e+02, 7.48280029e+02, 7.66469971e+02, 7.49869995e+02,
#          4.13940000e+06, 7.49869995e+02]]])

# %% [markdown]
# # Using bracket notation for extraction of data

# %%
mask
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 5 (items) x 1762 (major_axis) x 6 (minor_axis)
# Items axis: MSFT to AMZN
# Major_axis axis: 2010-01-04 00:00:00 to 2016-12-30 00:00:00
# Minor_axis axis: High to Adj Close

# %%
mask.minor_axis
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
mask["MSFT"]
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2010-01-04  31.100000  30.590000  30.620001  30.950001   38409100.0  24.525019
# 2010-01-05  31.100000  30.639999  30.850000  30.959999   49749600.0  24.532942
# 2010-01-06  31.080000  30.520000  30.879999  30.770000   58182400.0  24.382378
# 2010-01-07  30.700001  30.190001  30.629999  30.450001   50559700.0  24.128809
# 2010-01-08  30.879999  30.240000  30.280001  30.660000   51197400.0  24.295214
# 2010-01-11  30.760000  30.120001  30.709999  30.270000   68754700.0  23.986179
# 2010-01-12  30.400000  29.910000  30.150000  30.070000   65912100.0  23.827694
# 2010-01-13  30.520000  30.010000  30.260000  30.350000   51863500.0  24.049570
# 2010-01-14  31.100000  30.260000  30.309999  30.959999   63228100.0  24.532942
# 2010-01-15  31.240000  30.709999  31.080000  30.860001   79913200.0  24.453693
# 2010-01-19  31.240000  30.680000  30.750000  31.100000   46575700.0  24.643881
# 2010-01-20  30.940001  30.309999  30.809999  30.590000   54849500.0  24.239746
# 2010-01-21  30.719999  30.000000  30.610001  30.010000   73086700.0  23.780155
# 2010-01-22  30.200001  28.840000  30.000000  28.959999  102004600.0  22.948128
# 2010-01-25  29.660000  29.100000  29.240000  29.320000   63373000.0  23.233395
# 2010-01-26  29.850000  29.090000  29.200001  29.500000   66639900.0  23.376024
# 2016-12-19  63.770000  62.419998  62.560001  63.619999   34338200.0  60.686745
# 2016-12-20  63.799999  63.029999  63.689999  63.540001   26028400.0  60.610432
# 2016-12-21  63.700001  63.119999  63.430000  63.540001   17096300.0  60.610432
# 2016-12-22  64.099998  63.410000  63.840000  63.549999   22176600.0  60.619972
# 2016-12-23  63.540001  62.799999  63.450001  63.240002   12403800.0  60.324265
# 2016-12-27  64.070000  63.209999  63.209999  63.279999   11763200.0  60.362419
# 2016-12-28  63.400002  62.830002  63.400002  62.990002   14653300.0  60.085785
# 2016-12-29  63.200001  62.730000  62.860001  62.900002   10250600.0  59.999939
# 2016-12-30  62.990002  62.029999  62.959999  62.139999   25579900.0  59.274975
#
# [1762 rows x 6 columns]

# %%
mask.volume
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-123-83654d84b723> in <module>()
# ----> 1 mask.volume
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'Panel' object has no attribute 'volume'

# %%
mask.to_frame().head(5)
# Out:
#                            MSFT          GOOG          AAPL             Y  \
# Date       minor
# 2010-01-04 High    3.110000e+01  3.135796e+02  3.064286e+01    266.512878
#            Low     3.059000e+01  3.109545e+02  3.034000e+01    261.178406
#            Open    3.062000e+01  3.123044e+02  3.049000e+01    266.512878
#            Close   3.095000e+01  3.122048e+02  3.057286e+01    263.408295
#            Volume  3.840910e+07  3.927000e+06  1.234324e+08  14600.000000
#
#                            AMZN
# Date       minor
# 2010-01-04 High    1.366100e+02
#            Low     1.331400e+02
#            Open    1.362500e+02
#            Close   1.339000e+02
#            Volume  7.599900e+06

# %% [markdown]
# # Extracting with loc iloc and ix

# %%
mask
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 5 (items) x 1762 (major_axis) x 6 (minor_axis)
# Items axis: MSFT to AMZN
# Major_axis axis: 2010-01-04 00:00:00 to 2016-12-30 00:00:00
# Minor_axis axis: High to Adj Close

# %%
#since panel is decrepated we use multi-index method of extraction 
mask.loc["MSFT"].head(5)
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2010-01-04  31.100000  30.590000  30.620001  30.950001  38409100.0  24.525019
# 2010-01-05  31.100000  30.639999  30.850000  30.959999  49749600.0  24.532942
# 2010-01-06  31.080000  30.520000  30.879999  30.770000  58182400.0  24.382378
# 2010-01-07  30.700001  30.190001  30.629999  30.450001  50559700.0  24.128809
# 2010-01-08  30.879999  30.240000  30.280001  30.660000  51197400.0  24.295214

# %%
mask.loc[("MSFT", "2010-01-04")]
# Out:
# High         3.110000e+01
# Low          3.059000e+01
# Open         3.062000e+01
# Close        3.095000e+01
# Volume       3.840910e+07
# Adj Close    2.452502e+01
# Name: 2010-01-04 00:00:00, dtype: float64

# %%
mask.minor_axis
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
mask.items
# Out:
# Index(['MSFT', 'GOOG', 'AAPL', 'Y', 'AMZN'], dtype='object')

# %%
# companies = ["MSFT", "GOOG", "AAPL", "YHOO", "AMZN"]

# p = data.DataReader(name = companies, data_source = "yahoo", start = "2004-01-01", end ="2009-02-02")

# p
